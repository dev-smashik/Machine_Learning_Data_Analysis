# %% [markdown]
# <b>
# 1. Handle the Null value.<br>
# 2. Encode using the replace method.<br>
# 3. Use three types of encoding techniques for all the columns which contains categorical data.<br>
# 4. You have to use loop while encoding.
# </b>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <h5><b>Check Nulls</b></h5>

# %%
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# <b>In this dataframe there are no null value if found I will handle it otherwise go to next step.</b>

# %% [markdown]
# <h3><b>Describe DataFrame </b></h3>

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# <h3><b>1.Normalization / MinMax Scaler <br> 2.Standardization / Standard Scaler <br> 3.Robust Scaler <br> 4.Max Absolute Scaler</b></h3>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MaxAbsScaler

# %%
mms = MinMaxScaler()
ss = StandardScaler()
rs = RobustScaler()
mas = MaxAbsScaler()

# %% [markdown]
# <h5><b>Copy DataFrame for Scaling</b><h5/>

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()

# %% [markdown]
# <h3><b>Normalization / MinMax Scaler</b></h3>

# %%
df1.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df1["age"] = mms.fit_transform(df1[["age"]])
df1["bmi"] = mms.fit_transform(df1[["bmi"]])
df1["children"] = mms.fit_transform(df1[["children"]])
df1["charges"] = mms.fit_transform(df1[["charges"]])
df1.head()
# Out:
#         age  gender       bmi  children smoker     region   charges
# 0  0.021739  female  0.321227       0.0    yes  southwest  0.251611
# 1  0.000000    male  0.479150       0.2     no  southeast  0.009636
# 2  0.217391    male  0.458434       0.6     no  southeast  0.053115
# 3  0.326087    male  0.181464       0.0     no  northwest  0.333010
# 4  0.304348    male  0.347592       0.0     no  northwest  0.043816

# %% [markdown]
# <h3><b>Standardization/ Standard Scaler</b></h3>

# %%
df2.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df2["age"] = ss.fit_transform(df2[["age"]])
df2["bmi"] = ss.fit_transform(df2[["bmi"]])
df2["children"] = ss.fit_transform(df2[["children"]])
df2["charges"] = ss.fit_transform(df2[["charges"]])
df2.head()
# Out:
#         age  gender       bmi  children smoker     region   charges
# 0 -1.438764  female -0.453320 -0.908614    yes  southwest  0.298584
# 1 -1.509965    male  0.509621 -0.078767     no  southeast -0.953689
# 2 -0.797954    male  0.383307  1.580926     no  southeast -0.728675
# 3 -0.441948    male -1.305531 -0.908614     no  northwest  0.719843
# 4 -0.513149    male -0.292556 -0.908614     no  northwest -0.776802

# %% [markdown]
# <h2><b>Robust Scaler</b></h2>

# %%
df3.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df3["age"] = rs.fit_transform(df3[["age"]])
df3["bmi"] = rs.fit_transform(df3[["bmi"]])
df3["children"] = rs.fit_transform(df3[["children"]])
df3["charges"] = rs.fit_transform(df3[["charges"]])
df3.head()
# Out:
#         age  gender       bmi  children smoker     region   charges
# 0 -0.833333  female -0.297708      -0.5    yes  southwest  0.630515
# 1 -0.875000    male  0.401310       0.0     no  southeast -0.643422
# 2 -0.458333    male  0.309616       1.0     no  southeast -0.414515
# 3 -0.250000    male -0.916344      -0.5     no  northwest  1.059062
# 4 -0.291667    male -0.181006      -0.5     no  northwest -0.463475

# %% [markdown]
# <h2><b>Max Absolute Scaler</b></h2>

# %%
df4.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df4["age"] = mas.fit_transform(df4[["age"]])
df4["bmi"] = mas.fit_transform(df4[["bmi"]])
df4["children"] = mas.fit_transform(df4[["children"]])
df4["charges"] = mas.fit_transform(df4[["charges"]])
df4.head()
# Out:
#         age  gender       bmi  children smoker     region   charges
# 0  0.296875  female  0.525127       0.0    yes  southwest  0.264777
# 1  0.281250    male  0.635611       0.2     no  southeast  0.027059
# 2  0.437500    male  0.621118       0.6     no  southeast  0.069773
# 3  0.515625    male  0.427348       0.0     no  northwest  0.344744
# 4  0.500000    male  0.543572       0.0     no  northwest  0.060637

# %% [markdown]
# <h3><b>DataFrame Informations</b></h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# <h3><b>Remove Warnings!!</b></h3>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h5><b>Diagram </b></h5>

# %%
import seaborn as sns

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.histplot(df[["age"]])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df[["bmi"]])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df[["children"]])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df[["charges"]])
# Out:
# <Axes: ylabel='Count'>

# %%
df.corr(numeric_only = True)

#Show correspondence values numeric only
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# <b>show headmap diagram with correspondence values</b>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only = True), annot=True)
plt.savefig("Insurance.png")

# %% [markdown]
# <h5><b>Copy Dataframes</b></h5>

# %%
df5  = df.copy()
df6  = df.copy()
df7  = df.copy()
df8  = df.copy()
df9  = df.copy()
df10 = df.copy()
df11 = df.copy()
df12 = df.copy()
df13 = df.copy()
df14 = df.copy()
df15 = df.copy()
df16 = df.copy()

# %% [markdown]
# # Encoding Methods

# %% [markdown]
# <h3><b>Without Encoding method</b></h3>

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
gender1 = df.gender.unique()
smoker1 = df.smoker.unique()
region1 = df.region.unique()

# %%
print(gender1)
print(smoker1)
print(region1)
# Out:
# ['female' 'male']
# ['yes' 'no']
# ['southwest' 'southeast' 'northwest' 'northeast']

# %%
df.gender = df.gender.replace(['male', 'female'], [1,2])
df.smoker = df.smoker.replace(['yes', 'no'], [1,0])
df.region = df.region.replace(['southwest', 'southeast', 'northwest', 'northeast'], [1,2,3,4])
df.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       2  27.900         0       1       1  16884.92400
# 1   18       1  33.770         1       0       2   1725.55230
# 2   28       1  33.000         3       0       2   4449.46200
# 3   33       1  22.705         0       0       3  21984.47061
# 4   32       1  28.880         0       0       3   3866.85520

# %% [markdown]
# <h3><b>Label Encoding</b></h3>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df5.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df5.gender = le.fit_transform(df5.gender)
df5.smoker = le.fit_transform(df5.smoker)
df5.region = le.fit_transform(df5.region)
df5.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900         0       1       3  16884.92400
# 1   18       1  33.770         1       0       2   1725.55230
# 2   28       1  33.000         3       0       2   4449.46200
# 3   33       1  22.705         0       0       1  21984.47061
# 4   32       1  28.880         0       0       1   3866.85520

# %% [markdown]
# <h3><b>Label Encoding Using Loop</b></h3>

# %%
for col in df6.columns:
    if df6[col].dtype == np.number:
        continue
    else:
        df6[col] = le.fit_transform(df6[col])

# %%
df6.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0    1       0  27.900         0       1       3  16884.92400
# 1    0       1  33.770         1       0       2   1725.55230
# 2   10       1  33.000         3       0       2   4449.46200
# 3   15       1  22.705         0       0       1  21984.47061
# 4   14       1  28.880         0       0       1   3866.85520

# %% [markdown]
# <h3><b>Another Label Encoding Using Loop</b></h3>

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df7.columns:
    if is_numeric_dtype(df7[i]):
        continue
    else:
        df7[i] = le.fit_transform(df7[i])

# %%
df7.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900         0       1       3  16884.92400
# 1   18       1  33.770         1       0       2   1725.55230
# 2   28       1  33.000         3       0       2   4449.46200
# 3   33       1  22.705         0       0       1  21984.47061
# 4   32       1  28.880         0       0       1   3866.85520

# %% [markdown]
# # One Hot Encoding

# %%
dummy = pd.get_dummies(df8['region'], columns = df8.region.unique)
dummy.head()
# Out:
#    northeast  northwest  southeast  southwest
# 0      False      False      False       True
# 1      False      False       True      False
# 2      False      False       True      False
# 3      False       True      False      False
# 4      False       True      False      False

# %%
df8.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df8.drop('smoker', axis = 1, inplace = True)

# %%
df8.head()
# Out:
#    age  gender     bmi  children     region      charges
# 0   19  female  27.900         0  southwest  16884.92400
# 1   18    male  33.770         1  southeast   1725.55230
# 2   28    male  33.000         3  southeast   4449.46200
# 3   33    male  22.705         0  northwest  21984.47061
# 4   32    male  28.880         0  northwest   3866.85520

# %%
df8.drop('region', axis = 1, inplace = True)

# %%
df8.head()
# Out:
#    age  gender     bmi  children      charges
# 0   19  female  27.900         0  16884.92400
# 1   18    male  33.770         1   1725.55230
# 2   28    male  33.000         3   4449.46200
# 3   33    male  22.705         0  21984.47061
# 4   32    male  28.880         0   3866.85520

# %%
df8.drop('gender', axis = 1, inplace = True)

# %%
df8.head()
# Out:
#    age     bmi  children      charges
# 0   19  27.900         0  16884.92400
# 1   18  33.770         1   1725.55230
# 2   28  33.000         3   4449.46200
# 3   33  22.705         0  21984.47061
# 4   32  28.880         0   3866.85520

# %% [markdown]
# # Dummy variable Trap

# %%
dummy = pd.get_dummies(df9['region'], columns=df9.region.unique, drop_first = True, prefix='region')
dummy.head()
# Out:
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df10=pd.concat([df8,dummy], axis=1)
df10.head()
# Out:
#    age     bmi  children      charges  region_northwest  region_southeast  \
# 0   19  27.900         0  16884.92400             False             False
# 1   18  33.770         1   1725.55230             False              True
# 2   28  33.000         3   4449.46200             False              True
# 3   33  22.705         0  21984.47061              True             False
# 4   32  28.880         0   3866.85520              True             False
#
#    region_southwest
# 0              True
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# # One hot encoding using loop

# %%
cols = ['region']
for col in cols:
    dummy = pd.get_dummies(df11[col], drop_first=True, prefix='Region')
    df12 = pd.concat([df11,dummy], axis=1).drop(col,axis=1)
df12.head()
# Out:
#    age  gender     bmi  children smoker      charges  Region_northwest  \
# 0   19  female  27.900         0    yes  16884.92400             False
# 1   18    male  33.770         1     no   1725.55230             False
# 2   28    male  33.000         3     no   4449.46200             False
# 3   33    male  22.705         0     no  21984.47061              True
# 4   32    male  28.880         0     no   3866.85520              True
#
#    Region_southeast  Region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %% [markdown]
# # Ordinal Encoding

# %%
area = df13.region.unique()
area
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df13.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import OrdinalEncoder
od = OrdinalEncoder(categories=[area])

# %%
encoded_values = od.fit_transform(df13[['region']])
encoded_values
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [2.]])

# %%
encoded_values = pd.DataFrame(encoded_values, columns=['region'])

# %%
encoded_values.head()
# Out:
#    region
# 0     0.0
# 1     1.0
# 2     1.0
# 3     2.0
# 4     2.0

# %%
df13 = pd.concat([df13.drop('region', axis=1), encoded_values], axis=1)
df13.head()
# Out:
#    age  gender     bmi  children smoker      charges  region
# 0   19  female  27.900         0    yes  16884.92400     0.0
# 1   18    male  33.770         1     no   1725.55230     1.0
# 2   28    male  33.000         3     no   4449.46200     1.0
# 3   33    male  22.705         0     no  21984.47061     2.0
# 4   32    male  28.880         0     no   3866.85520     2.0

# %% [markdown]
# <h3><b>use loop - ordinary Encoding</b></h3>

# %%
df14.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0    1       0  27.900         0       1       3  16884.92400
# 1    0       1  33.770         1       0       2   1725.55230
# 2   10       1  33.000         3       0       2   4449.46200
# 3   15       1  22.705         0       0       1  21984.47061
# 4   14       1  28.880         0       0       1   3866.85520

# %%
od = OrdinalEncoder()
for i in df14.columns:
    if is_numeric_dtype(df14[i]):
        continue
    else:
        df14[i] = od.fit_transform(df14[[i]])

# %%
df14.head()
# Out:
#    age     bmi  children  smoker  region      charges  gender
# 0    1  27.900         0       1       3  16884.92400     0.0
# 1    0  33.770         1       0       2   1725.55230     1.0
# 2   10  33.000         3       0       2   4449.46200     1.0
# 3   15  22.705         0       0       1  21984.47061     1.0
# 4   14  28.880         0       0       1   3866.85520     1.0
